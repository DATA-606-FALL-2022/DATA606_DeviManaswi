# %% [markdown]
# ## Importing the packages

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
from datetime import timedelta
from datetime import date

# %% [markdown]
# ## Reading CSV files

# %%
final_df = pd.read_csv('Cleaned_Data.csv')

# %% [markdown]
# ### Displaying the data

# %%
final_df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %% [markdown]
# ## Describes the columns

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %% [markdown]
# ## Printing the number of rows and columns

# %%
print(final_df.shape)
# Out:
# (438557, 18)
# (1048575, 3)

# %% [markdown]
# ### EDA

# %%
final_df.hist(alpha=0.5, figsize=(12, 12))
plt.show()

# %%
# This list of lists contains all the columns which have binary categorical values
colRange = [['ID','CODE_GENDER','FLAG_OWN_CAR'],['FLAG_OWN_REALTY', 'CNT_CHILDREN','AMT_INCOME_TOTAL'] ,['NAME_INCOME_TYPE','NAME_EDUCATION_TYPE' ,'NAME_FAMILY_STATUS'] ,['NAME_HOUSING_TYPE','DAYS_BIRTH' ,'DAYS_EMPLOYED'],['FLAG_MOBIL','FLAG_WORK_PHONE','FLAG_PHONE'],['FLAG_EMAIL','CNT_FAM_MEMBERS','MONTHS_BALANCE']]
# This function prints the countplots counting the number of people in each category
def printCount(cols):
    fig, axes = plt.subplots(4,3, figsize=(20,20))
    row=0
    col=0
    p_count=1
    for row in range(4):
        for col in range(3):
            # reads column name from the list
            column = colRange[row][col]
            # plots the counts of the particular column
            sns.countplot(ax=axes[row,col],x=final_df[column],hue=final_df['STATUS'],palette="Set2")
            # sets the title of the corresponding plot along with plot number
            axes[row,col].set_title("Counts of {} (Plot {})".format(column,p_count))
            p_count += 1
# Calling the function
printCount(colRange)

# %%
sns.countplot(x='CODE_GENDER', palette="pastel", data=final_df, order=final_df.CODE_GENDER.value_counts().index)
plt.gcf().set_size_inches(10,10)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='NAME_INCOME_TYPE', palette="pastel", data=final_df, order=final_df.NAME_INCOME_TYPE.value_counts().index)
plt.gcf().set_size_inches(10,10)
plt.title('Income Type Distribution')
plt.xlabel('Income Type')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='NAME_EDUCATION_TYPE', palette="pastel", data=final_df, order=final_df.NAME_EDUCATION_TYPE.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Education Type Distribution')
plt.xlabel('Education Type')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='NAME_FAMILY_STATUS', palette="pastel", data=final_df, order=final_df.NAME_FAMILY_STATUS.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Family status Type Distribution')
plt.xlabel('Family Status Type')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x='NAME_HOUSING_TYPE', palette="pastel", data=final_df, order=final_df.NAME_HOUSING_TYPE.value_counts().index)
plt.gcf().set_size_inches(20,10)
plt.title('Housing Type Distribution')
plt.xlabel('Housing Type')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x="NAME_FAMILY_STATUS",palette="pastel", hue="CODE_GENDER", data=final_df)
plt.gcf().set_size_inches(20,10)
plt.title('gender vs Family status')
plt.xlabel('Family Type')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x="NAME_HOUSING_TYPE",palette="pastel", hue="CODE_GENDER", data=final_df)
plt.gcf().set_size_inches(20,10)
plt.title('gender vs housing type')
plt.xlabel('Family Type')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x="NAME_HOUSING_TYPE",palette="pastel", hue="NAME_FAMILY_STATUS", data=final_df)
plt.gcf().set_size_inches(20,5)
plt.title('family status vs housing type')
plt.xlabel('Family Type')
plt.xticks(rotation='horizontal')
plt.ylabel('Count')
plt.show()
